# %% [markdown]
# ### Prüfen NAs und 0 Values der Spalte 'curren_team' und 'team_class'

# %%
import pandas as pd
import os

# %%
df = pd.read_pickle('../../data/processed/15_cleaned_master_data.pkl')
