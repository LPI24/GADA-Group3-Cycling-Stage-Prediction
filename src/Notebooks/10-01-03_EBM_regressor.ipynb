# %% [markdown]
# Notebook 2: 03_model_regressor.ipynb
#
#     Fokus: Der kontinuierliche Ansatz (Direkte ordinale Regression auf die Werte 0, 1, 2, 3).
#
#     Inhalt: * Regressor-Baseline (ohne Interaktionen)
#
#         Schnelles Hyperparameter-Tuning für den Regressor (mit denselben Gewinner-Parametern: 5 Interaktionen, 8 Bags, 0.02 LR).
#
#         Globale Validierung: Mean Squared Error (MSE) & Mean Absolute Error (MAE).
#
#         Direkte Nutzung des .predict()-Werts als kontinuierlicher Score pro Fahrer.
#
#         Export dieser Regressor-Scores.
